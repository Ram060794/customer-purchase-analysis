# %%
import pandas as pd
print("pandas is working!")
# Out:
# pandas is working!

# %%
df = pd.read_csv("sample_dataset.csv")
df.head()
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  2002-10-20               35.47
# 1        26381  Michelle     Phelps    NaN  1985-10-24             2552.72
# 2       305449     Jacob   Williams      M  1981-10-25              115.97
# 3       988259    Nathan     Snyder      M  1977-10-26               11.31
# 4       764762   Crystal      Knapp      F  1951-11-02               62.21
#
#          Date               Merchant Name     Category
# 0  2023-04-03               Smith-Russell     Cosmetic
# 1  2023-07-17      Peck, Spence and Young       Travel
# 2  2023-09-20                  Steele Inc     Clothing
# 3  2023-01-11  Wilson, Wilson and Russell     Cosmetic
# 4  2023-06-13               Palmer-Hinton  Electronics

# %%
df.isnull().sum()
# Out:
# Customer ID              0
# Name                     0
# Surname                  0
# Gender                5047
# Birthdate                0
# Transaction Amount       0
# Date                     0
# Merchant Name            0
# Category                 0
# dtype: int64

# %%
df['Gender'] = df['Gender'].fillna("Unknown")

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Birthdate'] = pd.to_datetime(df['Birthdate'])

# %%
df['Age'] = 2026 - df['Birthdate'].dt.year

# %%
df['Month'] = df['Date'].dt.month

# %%
df.rename(columns={'Transaction Amount': 'Amount'}, inplace=True)

# %%
df.head()
# Out:
#    Customer ID      Name    Surname   Gender  Birthdate   Amount       Date  \
# 0       752858      Sean  Rodriguez        F 2002-10-20    35.47 2023-04-03
# 1        26381  Michelle     Phelps  Unknown 1985-10-24  2552.72 2023-07-17
# 2       305449     Jacob   Williams        M 1981-10-25   115.97 2023-09-20
# 3       988259    Nathan     Snyder        M 1977-10-26    11.31 2023-01-11
# 4       764762   Crystal      Knapp        F 1951-11-02    62.21 2023-06-13
#
#                 Merchant Name     Category  Age  Month
# 0               Smith-Russell     Cosmetic   24      4
# 1      Peck, Spence and Young       Travel   41      7
# 2                  Steele Inc     Clothing   45      9
# 3  Wilson, Wilson and Russell     Cosmetic   49      1
# 4               Palmer-Hinton  Electronics   75      6

# %%
df['Amount'].sum()
# Out:
# np.float64(22105961.970000003)

# %%
df['Amount'].mean()
# Out:
# np.float64(442.1192394)

# %%
df.groupby('Category')['Amount'].sum()
# Out:
# Category
# Clothing        1319342.47
# Cosmetic         876672.44
# Electronics     4394092.10
# Market          2151134.42
# Restaurant       464488.60
# Travel         12900231.94
# Name: Amount, dtype: float64

# %%
df.groupby('Month')['Amount'].sum()
# Out:
# Month
# 1     2345228.21
# 2     2148030.95
# 3     2396963.31
# 4     2289731.30
# 5     2460816.56
# 6     2254592.41
# 7     2475041.53
# 8     2391450.20
# 9     2274245.66
# 10    1069861.84
# Name: Amount, dtype: float64

# %%
df.to_csv("cleaned_data.csv", index=False)
